# %%
Immutable

# %%
a = (3,4)

# %%
a[1] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-23f2cf2bdf70> in <module>()
# ----> 1 a[1] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = '34'

# %%
a[1] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-23f2cf2bdf70> in <module>()
# ----> 1 a[1] = 3
#
# TypeError: 'str' object does not support item assignment

# %%
a = {'quiz': []}

# %%
a['quiz'].append(33)

# %%
a['quiz']
# Out:
# [33]

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3f786850e387> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = [3,5,6]

# %%
for e in a:
    if e == 5:
        del e

# %%
a
# Out:
# [3, 5, 6]

# %%
del a[1]

# %%
a
# Out:
# [3,
#  6,
#  4,
#  7,
#  5,
#  8,
#  6,
#  9,
#  7,
#  10,
#  8,
#  11,
#  9,
#  12,
#  10,
#  13,
#  11,
#  14,
#  12,
#  15,
#  13,
#  16,
#  14,
#  17,
#  15,
#  18,
#  16,
#  19,
#  17,
#  20,
#  18,
#  21,
#  19,
#  22,
#  20,
#  23,
#  21,
#  24,
#  22,
#  25,
#  23,
#  26,
#  24,
#  27,
#  25,
#  28,
#  26,
#  29,
#  27,
#  30,
#  28,
#  31,
#  29,
#  32,
#  30,
#  33,
#  31,
#  34,
#  32,
#  35,
#  33,
#  36,
#  34,
#  37,
#  35,
#  38,
#  36,
#  39,
#  37,
#  40,
#  38,
#  41,
#  39,
#  42,
#  40,
#  43,
#  41,
#  44,
#  42,
#  45,
#  43,
#  46,
#  44,
#  47,
#  45,
#  48,
#  46,
#  49,
#  47,
#  50,
#  48,
#  51,
#  49,
#  52,
#  50,
#  53,
#  51,
#  54,
#  52,
#  55,
#  53,
#  56,
#  54,
#  57,
#  55,
#  58,
#  56,
#  59,
#  57,
#  60,
#  58,
#  61,
#  59,
#  62,
#  60,
#  63,
#  61,
#  64,
#  62,
#  65,
#  63,
#  66,
#  64,
#  67,
#  65,
#  68,
#  66,
#  69,
#  67,
#  70,
#  68,
#  71,
#  69,
#  72,
#  70,
#  73,
#  71,
#  74,
#  72,
#  75,
#  73,
#  76,
#  74,
#  77,
# ...

# %%
for e in a:
    a.append(e + 1)
# to infinity, because a e = next(a)

# %%
a = [3,5]
for e in a:
    a.insert(0, e + 1)
# to infinity, because a e = next(a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-070bbfaace32> in <module>()
#       1 a = [3,5]
#       2 for e in a:
# ----> 3     a.insert(0, e + 1)
#
# KeyboardInterrupt:

# %%
int = 3
print(int)
print(int(int))
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-761301a30600> in <module>()
#       1 int = 3
#       2 print(int)
# ----> 3 print(int(int))
#
# TypeError: 'int' object is not callable

# %%
a = 3
b = 3

# %%
a is b
# Out:
# True

# %%
c = 3.0

# %%
c == a
# Out:
# True

# %%
c is a
# Out:
# False

# %%
a = ('',)

# %%
type(a)
# Out:
# tuple

# %%
class A:
    pass
a = A()
raise a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-87da8619d48c> in <module>()
#       2     pass
#       3 a = A()
# ----> 4 raise a
#
# TypeError: exceptions must derive from BaseException

# %%
",".join(['a','b',3,'3'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-368e89f7443f> in <module>()
# ----> 1 ",".join(['a','b',3,'3'])
#
# TypeError: sequence item 2: expected str instance, int found
